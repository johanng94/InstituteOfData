# %%
import pandas as pd

# %%
df_depress = pd.read_csv('depression_post_features_tfidf_256.csv')

# %%
pd.set_option('display.max_columns',50 )

# %%
df_depress
# Out:
#         subreddit            author        date  \
# 0      depression          peeepeed  2020/01/01
# 1      depression  cookieexpertuser  2020/01/01
# 2      depression        Ghostiez23  2020/01/01
# 3      depression          wisqrg50  2020/01/01
# 4      depression  arizonwatermelon  2020/01/01
# ...           ...               ...         ...
# 38028  depression     spearmintteas  2020/04/20
# 38029  depression    FlyingRadiator  2020/04/20
# 38030  depression        As_Roddeus  2020/04/20
# 38031  depression      FxS1nOfGreed  2020/04/20
# 38032  depression          epcool77  2020/04/20
#
#                                                     post  \
# 0      My heart aches but i cant break Recently my re...
# 1      Cheers I’m not sure if this is the right sub t...
# 2      Fuck titles. I’m depressed I feel so fucking w...
# 3      suffering from low energy I'm not exaggerating...
# 4      I can already tell This year is just going to ...
# ...

# %%
def new_csv(df):
    df = df[['subreddit','author','date','post']]
    
    return df
# new_csv(df_depress)

# %%
new_csv(df_depress).to_csv('depression_2020.csv', index = False)

# %%
depress_2018 = pd.read_csv('depression_2018_features_tfidf_256.csv')
new_csv(depress_2018).to_csv('depression_2018.csv', index = False)

depress_2019 = pd.read_csv('depression_2019_features_tfidf_256.csv')
new_csv(depress_2019).to_csv('depression_2019.csv', index = False)

# %%
suicide_2018 = pd.read_csv('suicidewatch_2018_features_tfidf_256.csv')
new_csv(suicide_2018).to_csv('suicide_2018.csv', index = False)

suicide_2019 = pd.read_csv('suicidewatch_2019_features_tfidf_256.csv')
new_csv(suicide_2019).to_csv('suicide_2019.csv', index = False)

suicide_2020 = pd.read_csv('suicidewatch_post_features_tfidf_256.csv')
new_csv(suicide_2018).to_csv('suicide_2020.csv', index = False)

# %%
alcohol_2018 = pd.read_csv('alcoholism_2018_features_tfidf_256.csv')
new_csv(alcohol_2018).to_csv('alcohol_2018.csv', index = False)

alcohol_2019 = pd.read_csv('alcoholism_2019_features_tfidf_256.csv')
new_csv(alcohol_2019).to_csv('alcohol_2019.csv', index = False)

alcohol_2020 = pd.read_csv('alcoholism_post_features_tfidf_256.csv')
new_csv(alcohol_2020).to_csv('alcohol_2020.csv', index = False)

# %%
anxiety_2018 = pd.read_csv('anxiety_2018_features_tfidf_256.csv')
new_csv(anxiety_2018).to_csv('anxiety_2018.csv', index = False)

anxiety_2019 = pd.read_csv('anxiety_2019_features_tfidf_256.csv')
new_csv(anxiety_2019).to_csv('anxiety_2019.csv', index = False)

anxiety_2020 = pd.read_csv('anxiety_post_features_tfidf_256.csv')
new_csv(anxiety_2020).to_csv('anxiety_2020.csv', index = False)

# %%
bipolar_2018 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/bipolarreddit_2018_features_tfidf_256.csv')
new_csv(bipolar_2018).to_csv('bipolar_2018.csv', index = False)

bipolar_2019 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/bipolarreddit_2019_features_tfidf_256.csv')
new_csv(bipolar_2019).to_csv('bipolar_2019.csv', index = False)

bipolar_2020 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/bipolarreddit_post_features_tfidf_256.csv')
new_csv(bipolar_2020).to_csv('bipolar_2020.csv', index = False)

# %%
schizo_2018 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/schizophrenia_2018_features_tfidf_256.csv')
new_csv(schizo_2018).to_csv('schizo_2018.csv', index = False)

schizo_2019 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/schizophrenia_2019_features_tfidf_256.csv')
new_csv(schizo_2019).to_csv('schizo_2019.csv', index = False)

schizo_2020 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/schizophrenia_post_features_tfidf_256.csv')
new_csv(schizo_2020).to_csv('schizo_2020.csv', index = False)

# %%
fitness_2018 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/fitness_2018_features_tfidf_256.csv')
new_csv(fitness_2018).to_csv('fitness_2018.csv', index = False)

fitness_2019 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/fitness_2019_features_tfidf_256.csv')
new_csv(fitness_2019).to_csv('fitness_2019.csv', index = False)

fitness_2020 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/fitness_post_features_tfidf_256.csv')
new_csv(fitness_2020).to_csv('fitness_2020.csv', index = False)

# %%
jokes_2018 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/jokes_2018_features_tfidf_256.csv')
new_csv(jokes_2018).to_csv('jokes_2018.csv', index = False)

jokes_2019 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/jokes_2019_features_tfidf_256.csv')
new_csv(jokes_2019).to_csv('jokes_2019.csv', index = False)

jokes_2020 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/jokes_post_features_tfidf_256.csv')
new_csv(jokes_2020).to_csv('jokes_2020.csv', index = False)

# %%
parenting_2018 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/parenting_2018_features_tfidf_256.csv')
new_csv(parenting_2018).to_csv('parenting_2018.csv', index = False)

parenting_2019 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/parenting_2019_features_tfidf_256.csv')
new_csv(parenting_2019).to_csv('parenting_2019.csv', index = False)

parenting_2020 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/parenting_post_features_tfidf_256.csv')
new_csv(parenting_2020).to_csv('parenting_2020.csv', index = False)

# %%
personalfinance_2018 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/personalfinance_2018_features_tfidf_256.csv')
new_csv(personalfinance_2018).to_csv('personalfinance_2018.csv', index = False)

personalfinance_2019 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/personalfinance_2019_features_tfidf_256.csv')
new_csv(personalfinance_2019).to_csv('personalfinance_2019.csv', index = False)

personalfinance_2020 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/personalfinance_post_features_tfidf_256.csv')
new_csv(personalfinance_2020).to_csv('personalfinance_2020.csv', index = False)

# %%
relationships_2018 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/relationships_2018_features_tfidf_256.csv')
new_csv(relationships_2018).to_csv('relationships_2018.csv', index = False)

relationships_2019 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/relationships_2019_features_tfidf_256.csv')
new_csv(relationships_2019).to_csv('relationships_2019.csv', index = False)

relationships_2020 = pd.read_csv('/Users/JohanNg/Institute of Data/Institute-of-Data/Capstone Project/Original CSV/relationships_post_features_tfidf_256.csv')
new_csv(relationships_2020).to_csv('relationships_2020.csv', index = False)
